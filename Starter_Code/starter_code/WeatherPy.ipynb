# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
# !pip install citipy
from citipy import citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.6.tar.gz (675 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kdtree>=0.12 (from citipy)
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675977 sha256=3362f952d28804bd3b70168f23ee1a49de3fa2f00ef3dc61aa0e3ffea0aeef03
#   Stored in directory: c:\users\rebec\appdata\local\pip\cache\wheels\41\82\37\8bb56372b0d828d226b83e0117780ecbe9f409100ac52364bd
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}") 


    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | poxoreo
# Processing Record 2 of Set 1 | abancay
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | utrik
# Processing Record 6 of Set 1 | namibe
# Processing Record 7 of Set 1 | invercargill
# Processing Record 8 of Set 1 | fontanelas
# Processing Record 9 of Set 1 | margaret river
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | west island
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | el burgo de osma
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | nadym
# Processing Record 18 of Set 1 | xilin hot
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | anadyr
# Processing Record 21 of Set 1 | bilibino
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | federacion
# Processing Record 24 of Set 1 | uturoa
# Processing Record 25 of Set 1 | motueka
# Processing Record 26 of Set 1 | fandriana
# Processing Record 27 of Set 1 | sinabang
# Processing Record 28 of Set 1 | san antonio de pale
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | bornu yassu
# Processing Record 31 of Set 1 | ponta delgada
# Processing Record 32 of Set 1 | island harbour
# Processing Record 33 of Set 1 | puerto baquerizo moreno
# Processing Record 34 of Set 1 | inhambane
# Processing Record 35 of Set 1 | maralal
# Processing Record 36 of Set 1 | stanley
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | korinthos
# Processing Record 39 of Set 1 | susuman
# Processing Record 40 of Set 1 | adamstown
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 1 | quellon
# Processing Record 44 of Set 1 | vorgashor
# Processing Record 45 of Set 1 | argo
# Processing Record 46 of Set 1 | papatowai
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | rabo de peixe
# Processing Record 50 of Set 1 | college
# Processing Record 0 of Set 2 | puerto gaitan
# Processing Record 1 of Set 2 | egilsstadir
# Processing Record 2 of Set 2 | tolanaro
# Processing Record 3 of Set 2 | richards bay
# Processing Record 4 of Set 2 | ta`u
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | mbaiki
# Processing Record 8 of Set 2 | turkestan
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | luderitz
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | keflavik
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | pangkalpinang
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | malkapur
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | laguna
# Processing Record 23 of Set 2 | kangal
# Processing Record 24 of Set 2 | salinopolis
# Processing Record 25 of Set 2 | maymana
# Processing Record 26 of Set 2 | rongelap
# Processing Record 27 of Set 2 | grytviken
# Processing Record 28 of Set 2 | mount pearl
# Processing Record 29 of Set 2 | whitehorse
# Processing Record 30 of Set 2 | lushun
# Processing Record 31 of Set 2 | bogale
# Processing Record 32 of Set 2 | leopoldina
# Processing Record 33 of Set 2 | fort st. john
# Processing Record 34 of Set 2 | puerto deseado
# Processing Record 35 of Set 2 | nagqu
# Processing Record 36 of Set 2 | dryden
# Processing Record 37 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 38 of Set 2 | kununurra
# Processing Record 39 of Set 2 | lata
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | yokadouma
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | blackmans bay
# Processing Record 44 of Set 2 | bassila
# Processing Record 45 of Set 2 | isafjordur
# Processing Record 46 of Set 2 | akureyri
# Processing Record 47 of Set 2 | rurrenabaque
# Processing Record 48 of Set 2 | kapa'a
# Processing Record 49 of Set 2 | maturin
# Processing Record 0 of Set 3 | virac
# Processing Record 1 of Set 3 | atafu village
# Processing Record 2 of Set 3 | sassandra
# Processing Record 3 of Set 3 | kutulik
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | dyurtyuli
# Processing Record 6 of Set 3 | saipan
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | naze
# Processing Record 9 of Set 3 | dali
# Processing Record 10 of Set 3 | morehead city
# Processing Record 11 of Set 3 | quincy
# Processing Record 12 of Set 3 | nelson bay
# Processing Record 13 of Set 3 | hami
# Processing Record 14 of Set 3 | lydenburg
# Processing Record 15 of Set 3 | calderitas
# Processing Record 16 of Set 3 | kingston
# Processing Record 17 of Set 3 | viqueque
# Processing Record 18 of Set 3 | wailua homesteads
# Processing Record 19 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 20 of Set 3 | shkoder
# Processing Record 21 of Set 3 | qaqortoq
# Processing Record 22 of Set 3 | bryne
# Processing Record 23 of Set 3 | douliu
# Processing Record 24 of Set 3 | amga
# Processing Record 25 of Set 3 | st. john's
# Processing Record 26 of Set 3 | tuzha
# Processing Record 27 of Set 3 | machico
# Processing Record 28 of Set 3 | labrador city
# Processing Record 29 of Set 3 | polyarnyy
# Processing Record 30 of Set 3 | chos malal
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | clarence town
# Processing Record 33 of Set 3 | mili
# Processing Record 34 of Set 3 | dabeiba
# Processing Record 35 of Set 3 | tomohon
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | mirny
# Processing Record 38 of Set 3 | al bayda'
# Processing Record 39 of Set 3 | ola
# Processing Record 40 of Set 3 | olonkinbyen
# Processing Record 41 of Set 3 | hawaiian paradise park
# Processing Record 42 of Set 3 | enewetak
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 3 | taoudenni
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | pointe-du-lac
# Processing Record 49 of Set 3 | conception bay south
# Processing Record 0 of Set 4 | kudahuvadhoo
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | chonchi
# Processing Record 3 of Set 4 | harstad
# Processing Record 4 of Set 4 | murzuq
# Processing Record 5 of Set 4 | road town
# Processing Record 6 of Set 4 | mangrol
# Processing Record 7 of Set 4 | berezovyy
# Processing Record 8 of Set 4 | flying fish cove
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | burang
# Processing Record 11 of Set 4 | dukhan
# Processing Record 12 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 13 of Set 4 | kenai
# Processing Record 14 of Set 4 | horta
# Processing Record 15 of Set 4 | torghay
# Processing Record 16 of Set 4 | kavaratti
# Processing Record 17 of Set 4 | rio grande
# Processing Record 18 of Set 4 | aoulef
# Processing Record 19 of Set 4 | charters towers
# Processing Record 20 of Set 4 | shinkafi
# Processing Record 21 of Set 4 | saint-pierre
# Processing Record 22 of Set 4 | boende
# Processing Record 23 of Set 4 | bikapur
# Processing Record 24 of Set 4 | mirabela
# Processing Record 25 of Set 4 | glen innes
# Processing Record 26 of Set 4 | kourou
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | puerto colombia
# Processing Record 29 of Set 4 | tsiombe
# Processing Record 30 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 31 of Set 4 | sikasso
# Processing Record 32 of Set 4 | chiredzi
# Processing Record 33 of Set 4 | udachny
# Processing Record 34 of Set 4 | ugoofaaru
# Processing Record 35 of Set 4 | price
# Processing Record 36 of Set 4 | ust-nera
# Processing Record 37 of Set 4 | bazar-e yakawlang
# City not found. Skipping...
# Processing Record 38 of Set 4 | avarua
# Processing Record 39 of Set 4 | choyr
# Processing Record 40 of Set 4 | amos
# Processing Record 41 of Set 4 | par naogaon
# Processing Record 42 of Set 4 | lake albert
# Processing Record 43 of Set 4 | holmsund
# Processing Record 44 of Set 4 | port mathurin
# Processing Record 45 of Set 4 | jamestown
# Processing Record 46 of Set 4 | grimes
# Processing Record 47 of Set 4 | recani
# Processing Record 48 of Set 4 | bath
# Processing Record 49 of Set 4 | kyosai
# Processing Record 0 of Set 5 | benguela
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | pedernales
# Processing Record 3 of Set 5 | inongo
# Processing Record 4 of Set 5 | maiwut
# City not found. Skipping...
# Processing Record 5 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 6 of Set 5 | koneurgench
# City not found. Skipping...
# Processing Record 7 of Set 5 | midvagur
# Processing Record 8 of Set 5 | kayenta
# Processing Record 9 of Set 5 | al jawf
# Processing Record 10 of Set 5 | colimes
# Processing Record 11 of Set 5 | kargasok
# Processing Record 12 of Set 5 | fort mcmurray
# Processing Record 13 of Set 5 | las heras
# Processing Record 14 of Set 5 | revda
# Processing Record 15 of Set 5 | tual
# Processing Record 16 of Set 5 | natal
# Processing Record 17 of Set 5 | mahina
# Processing Record 18 of Set 5 | almhult
# City not found. Skipping...
# Processing Record 19 of Set 5 | afaahiti
# Processing Record 20 of Set 5 | mossel bay
# Processing Record 21 of Set 5 | sao gabriel da cachoeira
# Processing Record 22 of Set 5 | eureka
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | puerto san jose
# Processing Record 25 of Set 5 | al kharijah
# Processing Record 26 of Set 5 | sydney
# Processing Record 27 of Set 5 | celestun
# Processing Record 28 of Set 5 | badger
# Processing Record 29 of Set 5 | aasiaat
# Processing Record 30 of Set 5 | mo i rana
# Processing Record 31 of Set 5 | kijang
# Processing Record 32 of Set 5 | peniche
# Processing Record 33 of Set 5 | ma'rib
# Processing Record 34 of Set 5 | lodwar
# Processing Record 35 of Set 5 | paracuru
# Processing Record 36 of Set 5 | weno
# Processing Record 37 of Set 5 | xi'an
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | beloyarskiy
# Processing Record 40 of Set 5 | fort bragg
# Processing Record 41 of Set 5 | buka
# Processing Record 42 of Set 5 | nyurba
# Processing Record 43 of Set 5 | maumere
# Processing Record 44 of Set 5 | salmas
# Processing Record 45 of Set 5 | trairi
# Processing Record 46 of Set 5 | san pedro carcha
# Processing Record 47 of Set 5 | dawei
# Processing Record 48 of Set 5 | gadzhiyevo
# Processing Record 49 of Set 5 | east london
# Processing Record 0 of Set 6 | taro
# Processing Record 1 of Set 6 | porto novo
# Processing Record 2 of Set 6 | prado
# Processing Record 3 of Set 6 | saulkrasti
# Processing Record 4 of Set 6 | praia
# Processing Record 5 of Set 6 | timimoun
# Processing Record 6 of Set 6 | telhara
# Processing Record 7 of Set 6 | hadibu
# Processing Record 8 of Set 6 | luancheng
# Processing Record 9 of Set 6 | flin flon
# Processing Record 10 of Set 6 | holualoa
# Processing Record 11 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 12 of Set 6 | wanning
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | pitanga
# Processing Record 15 of Set 6 | huadian
# Processing Record 16 of Set 6 | yuxia
# Processing Record 17 of Set 6 | huarmey
# Processing Record 18 of Set 6 | mudgee
# Processing Record 19 of Set 6 | noumea
# Processing Record 20 of Set 6 | fale old settlement
# Processing Record 21 of Set 6 | tevragh zeina
# City not found. Skipping...
# Processing Record 22 of Set 6 | santa maria
# Processing Record 23 of Set 6 | margate
# Processing Record 24 of Set 6 | taber
# Processing Record 25 of Set 6 | cruzeiro do sul
# Processing Record 26 of Set 6 | laascaanood
# Processing Record 27 of Set 6 | toropets
# Processing Record 28 of Set 6 | taguatinga
# Processing Record 29 of Set 6 | anavyssos
# Processing Record 30 of Set 6 | remire-montjoly
# Processing Record 31 of Set 6 | ijuw
# City not found. Skipping...
# Processing Record 32 of Set 6 | madang
# Processing Record 33 of Set 6 | jinshi
# Processing Record 34 of Set 6 | brumunddal
# Processing Record 35 of Set 6 | zalingei
# Processing Record 36 of Set 6 | pyapon
# Processing Record 37 of Set 6 | san clemente del tuyu
# Processing Record 38 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 39 of Set 6 | sandnessjoen
# Processing Record 40 of Set 6 | jefferson city
# Processing Record 41 of Set 6 | vilyuysk
# Processing Record 42 of Set 6 | nuku'alofa
# Processing Record 43 of Set 6 | ketchikan
# Processing Record 44 of Set 6 | dongola
# Processing Record 45 of Set 6 | borisoglebskiy
# Processing Record 46 of Set 6 | santa cruz de las flores
# Processing Record 47 of Set 6 | kaiapoi
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | vila franca do campo
# Processing Record 0 of Set 7 | freetown
# Processing Record 1 of Set 7 | hun
# Processing Record 2 of Set 7 | kharp
# Processing Record 3 of Set 7 | nzega
# Processing Record 4 of Set 7 | inarajan village
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | cadale
# Processing Record 7 of Set 7 | la passe
# Processing Record 8 of Set 7 | scottburgh
# Processing Record 9 of Set 7 | lorengau
# Processing Record 10 of Set 7 | coondapoor
# Processing Record 11 of Set 7 | rabaul
# Processing Record 12 of Set 7 | amarpur
# Processing Record 13 of Set 7 | hope
# Processing Record 14 of Set 7 | haiku-pauwela
# Processing Record 15 of Set 7 | paranhos
# Processing Record 16 of Set 7 | noosa heads
# Processing Record 17 of Set 7 | znamenka
# Processing Record 18 of Set 7 | sarupathar
# Processing Record 19 of Set 7 | najaf
# Processing Record 20 of Set 7 | alice springs
# Processing Record 21 of Set 7 | dzhalagash
# Processing Record 22 of Set 7 | pandan
# Processing Record 23 of Set 7 | chibougamau
# Processing Record 24 of Set 7 | colonia
# Processing Record 25 of Set 7 | la gi
# Processing Record 26 of Set 7 | gaspe
# Processing Record 27 of Set 7 | saint-joseph
# Processing Record 28 of Set 7 | dadukou
# Processing Record 29 of Set 7 | sitka
# Processing Record 30 of Set 7 | port saint john's
# Processing Record 31 of Set 7 | muramatsu
# Processing Record 32 of Set 7 | el calafate
# Processing Record 33 of Set 7 | palangkaraya
# Processing Record 34 of Set 7 | klyuchi
# Processing Record 35 of Set 7 | villa juarez
# Processing Record 36 of Set 7 | mineros
# Processing Record 37 of Set 7 | yola
# Processing Record 38 of Set 7 | tobias barreto
# Processing Record 39 of Set 7 | tshikapa
# Processing Record 40 of Set 7 | 'ibri
# City not found. Skipping...
# Processing Record 41 of Set 7 | tazovsky
# Processing Record 42 of Set 7 | arkhangel'sk
# Processing Record 43 of Set 7 | ang thong
# Processing Record 44 of Set 7 | kencong
# Processing Record 45 of Set 7 | tazacorte
# Processing Record 46 of Set 7 | belle fourche
# Processing Record 47 of Set 7 | sathupalli
# Processing Record 48 of Set 7 | solnechnyy
# Processing Record 49 of Set 7 | tabou
# Processing Record 0 of Set 8 | yenangyaung
# Processing Record 1 of Set 8 | amungan
# Processing Record 2 of Set 8 | pierre
# Processing Record 3 of Set 8 | daru
# Processing Record 4 of Set 8 | puerto ayacucho
# Processing Record 5 of Set 8 | al hilaliyya
# Processing Record 6 of Set 8 | homer
# Processing Record 7 of Set 8 | crane
# Processing Record 8 of Set 8 | saint louis
# Processing Record 9 of Set 8 | beyneu
# Processing Record 10 of Set 8 | espargos
# City not found. Skipping...
# Processing Record 11 of Set 8 | oranjemund
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | calca
# Processing Record 14 of Set 8 | san luis ixcan
# Processing Record 15 of Set 8 | babadag
# Processing Record 16 of Set 8 | taltal
# Processing Record 17 of Set 8 | kalmunai
# Processing Record 18 of Set 8 | itaituba
# Processing Record 19 of Set 8 | kastamonu
# Processing Record 20 of Set 8 | san miguel
# Processing Record 21 of Set 8 | plymouth
# Processing Record 22 of Set 8 | marang
# Processing Record 23 of Set 8 | san luis de la loma
# Processing Record 24 of Set 8 | portland
# Processing Record 25 of Set 8 | zapolyarnyy
# Processing Record 26 of Set 8 | kaihua
# Processing Record 27 of Set 8 | swan hill
# Processing Record 28 of Set 8 | kalabo
# Processing Record 29 of Set 8 | port elizabeth
# Processing Record 30 of Set 8 | hovd
# Processing Record 31 of Set 8 | vadso
# Processing Record 32 of Set 8 | mandera
# Processing Record 33 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 34 of Set 8 | cabo san lucas
# Processing Record 35 of Set 8 | san andres
# Processing Record 36 of Set 8 | minas de marcona
# Processing Record 37 of Set 8 | mejit
# Processing Record 38 of Set 8 | peace river
# Processing Record 39 of Set 8 | igrim
# Processing Record 40 of Set 8 | wuyang
# Processing Record 41 of Set 8 | brookings
# Processing Record 42 of Set 8 | balaka
# Processing Record 43 of Set 8 | barreirinhas
# Processing Record 44 of Set 8 | shingu
# Processing Record 45 of Set 8 | newman
# Processing Record 46 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 47 of Set 8 | summerland
# Processing Record 48 of Set 8 | carnarvon
# Processing Record 49 of Set 8 | miyaly
# Processing Record 0 of Set 9 | lethem
# Processing Record 1 of Set 9 | nova sintra
# Processing Record 2 of Set 9 | buchanan
# Processing Record 3 of Set 9 | urengoy
# Processing Record 4 of Set 9 | iskateley
# Processing Record 5 of Set 9 | licata
# Processing Record 6 of Set 9 | atar
# Processing Record 7 of Set 9 | pisco
# Processing Record 8 of Set 9 | nizhneangarsk
# Processing Record 9 of Set 9 | franeker
# Processing Record 10 of Set 9 | qamdo
# Processing Record 11 of Set 9 | pen
# Processing Record 12 of Set 9 | neftekumsk
# Processing Record 13 of Set 9 | ciudad acuna
# Processing Record 14 of Set 9 | dzilam gonzalez
# Processing Record 15 of Set 9 | port moresby
# Processing Record 16 of Set 9 | carinhanha
# Processing Record 17 of Set 9 | kurchatov
# Processing Record 18 of Set 9 | warrnambool
# Processing Record 19 of Set 9 | conduaga
# Processing Record 20 of Set 9 | toliara
# Processing Record 21 of Set 9 | ulan bator
# Processing Record 22 of Set 9 | dul'durga
# Processing Record 23 of Set 9 | wynyard
# Processing Record 24 of Set 9 | antalaha
# Processing Record 25 of Set 9 | wainwright
# Processing Record 26 of Set 9 | tallinn
# Processing Record 27 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 28 of Set 9 | chornomors'k
# Processing Record 29 of Set 9 | bangjun
# Processing Record 30 of Set 9 | sampit
# Processing Record 31 of Set 9 | alaghsas
# Processing Record 32 of Set 9 | sao borja
# Processing Record 33 of Set 9 | pocone
# Processing Record 34 of Set 9 | krasnyy chikoy
# Processing Record 35 of Set 9 | mwinilunga
# Processing Record 36 of Set 9 | tarawa
# Processing Record 37 of Set 9 | hithadhoo
# Processing Record 38 of Set 9 | rauma
# Processing Record 39 of Set 9 | nogliki
# Processing Record 40 of Set 9 | bratsk
# Processing Record 41 of Set 9 | ambato
# Processing Record 42 of Set 9 | sao raimundo das mangabeiras
# Processing Record 43 of Set 9 | akalkot
# Processing Record 44 of Set 9 | spoleto
# Processing Record 45 of Set 9 | carutapera
# Processing Record 46 of Set 9 | sabha
# Processing Record 47 of Set 9 | berdigestyakh
# Processing Record 48 of Set 9 | kapuskasing
# Processing Record 49 of Set 9 | fazilpur
# Processing Record 0 of Set 10 | aykhal
# Processing Record 1 of Set 10 | bopolu
# Processing Record 2 of Set 10 | qui nhon
# Processing Record 3 of Set 10 | hammerfest
# Processing Record 4 of Set 10 | sao joao da barra
# Processing Record 5 of Set 10 | griffith
# Processing Record 6 of Set 10 | xining
# Processing Record 7 of Set 10 | paita
# Processing Record 8 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 9 of Set 10 | san sebastian de la gomera
# Processing Record 10 of Set 10 | hohhot
# Processing Record 11 of Set 10 | carlsbad
# Processing Record 12 of Set 10 | al hada
# Processing Record 13 of Set 10 | volodymyrets'
# City not found. Skipping...
# Processing Record 14 of Set 10 | manado
# Processing Record 15 of Set 10 | el dorado
# Processing Record 16 of Set 10 | tingo maria
# Processing Record 17 of Set 10 | fort-shevchenko
# Processing Record 18 of Set 10 | acapulco de juarez
# Processing Record 19 of Set 10 | al mayadin
# Processing Record 20 of Set 10 | virginia
# Processing Record 21 of Set 10 | chui
# Processing Record 22 of Set 10 | arys
# Processing Record 23 of Set 10 | kathmandu
# Processing Record 24 of Set 10 | new norfolk
# Processing Record 25 of Set 10 | lazaro cardenas
# Processing Record 26 of Set 10 | floro
# Processing Record 27 of Set 10 | glendive
# Processing Record 28 of Set 10 | labuan
# Processing Record 29 of Set 10 | soller
# Processing Record 30 of Set 10 | barra de santo antonio
# Processing Record 31 of Set 10 | kutum
# Processing Record 32 of Set 10 | maghar
# Processing Record 33 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 10 | ujae
# Processing Record 35 of Set 10 | vorkuta
# Processing Record 36 of Set 10 | turinsk
# Processing Record 37 of Set 10 | mariental
# Processing Record 38 of Set 10 | asau
# Processing Record 39 of Set 10 | selfoss
# Processing Record 40 of Set 10 | ashburton
# Processing Record 41 of Set 10 | dunkwa
# Processing Record 42 of Set 10 | san fernando
# Processing Record 43 of Set 10 | craig
# Processing Record 44 of Set 10 | hurricane
# Processing Record 45 of Set 10 | figuig (centre)
# Processing Record 46 of Set 10 | atabey
# Processing Record 47 of Set 10 | luena
# Processing Record 48 of Set 10 | sabalgarh
# Processing Record 49 of Set 10 | jingdezhen
# Processing Record 0 of Set 11 | guerrero negro
# Processing Record 1 of Set 11 | kisangani
# Processing Record 2 of Set 11 | birao
# Processing Record 3 of Set 11 | aleg
# Processing Record 4 of Set 11 | santa cruz
# Processing Record 5 of Set 11 | glace bay
# Processing Record 6 of Set 11 | bagontapay
# Processing Record 7 of Set 11 | nicoya
# Processing Record 8 of Set 11 | i-n-salah
# Processing Record 9 of Set 11 | arno
# Processing Record 10 of Set 11 | mahibadhoo
# Processing Record 11 of Set 11 | antofagasta
# Processing Record 12 of Set 11 | boa vista
# Processing Record 13 of Set 11 | brigantine
# Processing Record 14 of Set 11 | lompoc
# Processing Record 15 of Set 11 | mount airy
# Processing Record 16 of Set 11 | santa cruz cabralia
# Processing Record 17 of Set 11 | cole harbour
# Processing Record 18 of Set 11 | valday
# Processing Record 19 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 20 of Set 11 | constantia
# Processing Record 21 of Set 11 | timmins
# Processing Record 22 of Set 11 | nanga eboko
# Processing Record 23 of Set 11 | bel ombre
# Processing Record 24 of Set 11 | ghanzi
# Processing Record 25 of Set 11 | nago
# Processing Record 26 of Set 11 | cox's bazar
# Processing Record 27 of Set 11 | khromtau
# Processing Record 28 of Set 11 | kamaishi
# Processing Record 29 of Set 11 | duiwelskloof
# Processing Record 30 of Set 11 | papao
# Processing Record 31 of Set 11 | kirakira
# Processing Record 32 of Set 11 | carauari
# Processing Record 33 of Set 11 | aldinga beach
# Processing Record 34 of Set 11 | duncan town
# City not found. Skipping...
# Processing Record 35 of Set 11 | awjilah
# Processing Record 36 of Set 11 | bikenibeu village
# Processing Record 37 of Set 11 | cambria
# Processing Record 38 of Set 11 | vielsalm
# Processing Record 39 of Set 11 | machiques
# Processing Record 40 of Set 11 | ust'-uda
# Processing Record 41 of Set 11 | caleta de carquin
# Processing Record 42 of Set 11 | la punta
# Processing Record 43 of Set 11 | vilyuchinsk
# Processing Record 44 of Set 11 | togur
# Processing Record 45 of Set 11 | kailua-kona
# Processing Record 46 of Set 11 | gadani
# Processing Record 47 of Set 11 | sidhauli
# Processing Record 48 of Set 11 | padangsidempuan
# Processing Record 49 of Set 11 | belmonte
# Processing Record 0 of Set 12 | rio brilhante
# Processing Record 1 of Set 12 | nuuk
# Processing Record 2 of Set 12 | zachary
# Processing Record 3 of Set 12 | malvan
# Processing Record 4 of Set 12 | ivdel'
# Processing Record 5 of Set 12 | greenland
# Processing Record 6 of Set 12 | walvis bay
# Processing Record 7 of Set 12 | bubaque
# Processing Record 8 of Set 12 | chutove
# Processing Record 9 of Set 12 | bonthe
# Processing Record 10 of Set 12 | payakumbuh
# Processing Record 11 of Set 12 | alik ghund
# Processing Record 12 of Set 12 | kerikeri
# Processing Record 13 of Set 12 | engenheiro beltrao
# Processing Record 14 of Set 12 | axim
# Processing Record 15 of Set 12 | santo nino
# Processing Record 16 of Set 12 | constitucion
# Processing Record 17 of Set 12 | san juan
# Processing Record 18 of Set 12 | altai
# Processing Record 19 of Set 12 | gorontalo
# Processing Record 20 of Set 12 | lospalos
# Processing Record 21 of Set 12 | kulhudhuffushi
# Processing Record 22 of Set 12 | xuddur
# Processing Record 23 of Set 12 | vila velha
# Processing Record 24 of Set 12 | usogorsk
# Processing Record 25 of Set 12 | mungia
# Processing Record 26 of Set 12 | lloydminster
# Processing Record 27 of Set 12 | santa terezinha
# Processing Record 28 of Set 12 | bodaybo
# Processing Record 29 of Set 12 | san pedro pochutla
# Processing Record 30 of Set 12 | kuta
# Processing Record 31 of Set 12 | luau
# Processing Record 32 of Set 12 | salekhard
# Processing Record 33 of Set 12 | fonte boa
# Processing Record 34 of Set 12 | sinop
# Processing Record 35 of Set 12 | khovd
# Processing Record 36 of Set 12 | zhanaozen
# Processing Record 37 of Set 12 | coquimbo
# Processing Record 38 of Set 12 | gebeit
# Processing Record 39 of Set 12 | coari
# Processing Record 40 of Set 12 | ceeldheer
# Processing Record 41 of Set 12 | taulaga
# Processing Record 42 of Set 12 | saint-paul
# Processing Record 43 of Set 12 | empalme
# Processing Record 44 of Set 12 | lake havasu city
# Processing Record 45 of Set 12 | alofi
# Processing Record 46 of Set 12 | camden
# Processing Record 47 of Set 12 | nemuro
# Processing Record 48 of Set 12 | saudarkrokur
# Processing Record 49 of Set 12 | pokhara
# Processing Record 0 of Set 13 | viedma
# Processing Record 1 of Set 13 | ocean pointe
# City not found. Skipping...
# Processing Record 2 of Set 13 | siwa oasis
# Processing Record 3 of Set 13 | saposoa
# Processing Record 4 of Set 13 | brak
# Processing Record 5 of Set 13 | palikir - national government center
# Processing Record 6 of Set 13 | fort stockton
# Processing Record 7 of Set 13 | suez
# Processing Record 8 of Set 13 | heunghae
# Processing Record 9 of Set 13 | khandyga
# Processing Record 10 of Set 13 | khlong luang
# Processing Record 11 of Set 13 | pimentel
# Processing Record 12 of Set 13 | mizdah
# Processing Record 13 of Set 13 | magadan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      poxoreo -15.8372  -54.3892     78.51        77          89        4.29
# 1      abancay -13.6339  -72.8814     64.06        80          80        4.70
# 2  port alfred -33.5906   26.8910     65.17        95         100        1.99
# 3       bethel  41.3712  -73.4140     33.89        75         100        3.44
# 4        utrik  11.2278  169.8474     80.01        67          38       17.92
#
#   Country        Date
# 0      BR  1704672251
# 1      PE  1704672251
# 2      ZA  1704672252
# 3      US  1704672252
# 4      MH  1704672252

# %%
# Export the City_Data into a csv
city_data_df.to_csv("C:\\Users\\rebec\\Desktop\\python-api-challenge--6\\city_data", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("C:\\Users\\rebec\\Desktop\\python-api-challenge--6\\city_data", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            poxoreo -15.8372  -54.3892     78.51        77          89
# 1            abancay -13.6339  -72.8814     64.06        80          80
# 2        port alfred -33.5906   26.8910     65.17        95         100
# 3             bethel  41.3712  -73.4140     33.89        75         100
# 4              utrik  11.2278  169.8474     80.01        67          38
#
#          Wind Speed Country        Date
# City_ID
# 0              4.29      BR  1704672251
# 1              4.70      PE  1704672251
# 2              1.99      ZA  1704672252
# 3              3.44      US  1704672252
# 4             17.92      MH  1704672252

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]

plt.scatter(lats,
            max_temps,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\rebec\\Desktop\\python-api-challenge--6//Fig1.png")
max_temps = city_data_df["Max Temp"]



# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lats = city_data_df["Lat"]
humidity = city_data_df["Humidity"]

plt.scatter(lats,
            humidity,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\rebec\\Desktop\\python-api-challenge--6\\Fig2.png")


# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lats = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]

plt.scatter(lats,
            cloudiness,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\rebec\\Desktop\\python-api-challenge--6\\Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lats = city_data_df["Lat"]
wind_speed = city_data_df["Wind Speed"]

plt.scatter(lats,
            wind_speed,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Windspeed mph")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:\\Users\\rebec\\Desktop\\python-api-challenge--6\\Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                  bethel  41.3712  -73.4140     33.89        75         100
# 4                   utrik  11.2278  169.8474     80.01        67          38
# 7              fontanelas  38.8472   -9.4372     48.16        80          16
# 13       el burgo de osma  41.5862   -3.0652     30.15        91          15
# 14              ilulissat  69.2167  -51.1000     19.42        68         100
#
#          Wind Speed Country        Date
# City_ID
# 3              3.44      US  1704672252
# 4             17.92      MH  1704672252
# 7              2.15      PT  1704672253
# 13             8.21      ES  1704672255
# 14            17.27      GL  1704672255

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             poxoreo -15.8372  -54.3892     78.51        77          89
# 1             abancay -13.6339  -72.8814     64.06        80          80
# 2         port alfred -33.5906   26.8910     65.17        95         100
# 5              namibe -15.1961   12.1522     72.39        82          99
# 6        invercargill -46.4000  168.3500     68.02        70         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.29      BR  1704672251
# 1              4.70      PE  1704672251
# 2              1.99      ZA  1704672252
# 5              6.24      AO  1704672253
# 6              1.99      NZ  1704672198

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Temperature")
    print(f"The r-squared is: {rvalue}")

x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Linear regression on Northern Hemisphere
# ----> 2 (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
#       3 regress_values = x_values * slope + intercept
#       4 line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
#
# NameError: name 'x_values' is not defined

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Max Temp")
    print(f"The r-squared is: {rvalue}")
    
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel("Humidity")
    print(f"The r-squared is: {rvalue}")
    
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel("Humidity")
    print(f"The r-squared is: {rvalue}")

x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Southern Hemisphere
# ----> 2 (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
#       3 regress_values = x_values * slope + intercept
#       4 line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
#
# NameError: name 'x_values' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel("Cloudiness")
    print(f"The r-squared is: {rvalue}")

x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel("Cloudiness")
    print(f"The r-squared is: {rvalue}")

x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel("Wind Speed")
    print(f"The r-squared is: {rvalue}")

x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (40,25))
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

def plot_linear_regression(x_values,y_values,title,text_coordinates):
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel("Wind Speed")
    print(f"The r-squared is: {rvalue}")

x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (-30,30))
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
Outside of latitude and max temp, there don't seem to be amy linier relationships showen, perhaps there are other types of relationships.
